# %% [markdown]
# <a href="https://colab.research.google.com/github/NaithaniAR/-Play-Store-App-Review-Analysis/blob/main/EDA_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> INTRODUCTION </b>
#
# # <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# *  #  Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.
# *  # Explore and analyze the data to discover key factors responsible for app engagement and success.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df=pd.read_csv("/content/drive/MyDrive/Datasets/GG/Play Store Data.csv")
#df1=pd.read_csv("/content/drive/MyDrive/Datasets/GG/User Reviews.csv")

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %%
df.info()
 # We observe that we have 13 variables in columns of df , with one glance we observe that Data type of certain variables such as price, installs .. etc need to be converted to numeric type. 
 # After removing duplicate values we are left with a total of 10358 values of 10841

# %%
df.isnull().sum()

# %% [markdown]
# # Let check the DataFrame for duplicate values

# %%
df.shape # df has 10841 observation before cleaning.
# Out:
# (10841, 13)

# %%
df[df.duplicated()]  #df has 483 observation before cleaning.
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# 229      80805  Varies with device    5,000,000+  Free     0       Everyone
# 236     159872  Varies with device   10,000,000+  Free     0       Everyone
# 239      70991  Varies with device    5,000,000+  Free     0       Everyone
# 256      31614                 37M   10,000,000+  Free     0       Everyone
# 261       6989  Varies with device    1,000,000+  Free     0       Everyone
# ...        ...                 ...           ...   ...   ...            ...
# 8643    404610  Varies with device   10,000,000+  Free     0       Everyone
# 8654     25370  Varies with device    1,000,000+  Free     0       Everyone
# 8658   2401017  Varies with device  100,000,000+  Free     0       Everyone
# 10049      123                 86M       10,000+  Free     0       Everyone
# 10768       63                 24M       10,000+  Free     0       Everyone
#
#              Genres       Last Updated         Current Ver         Android Ver
# 229        Business  February 26, 2018  Varies with device        4.0.3 and up
# 236        Business      July 31, 2018  Varies with device  Varies with device
# 239        Business      July 24, 2018    2.19.0.204537701          4.4 and up
# 256        Business      July 20, 2018      4.1.28165.0716          4.0 and up
# 261        Business      July 16, 2018           4.3.0.508          4.4 and up
# ...             ...                ...                 ...                 ...
# 8643   Productivity      April 6, 2018  Varies with device  Varies with device
# 8654   Productivity     August 6, 2018  Varies with device  Varies with device
# 8658   Productivity      June 27, 2018  Varies with device  Varies with device
# 10049       Medical       June 1, 2018              0.6.88          5.0 and up
# 10768       Medical      June 22, 2018               2.3.1          5.0 and up
#
# [483 rows x 13 columns]

# %%
before = len(df.index)
print('Total entries with duplicates were '+ (str(before)))
ddf=df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=True) #Drop duplicates with a value in a specific column.
after = len(ddf.index)
print('Total entries after duplicates were dropped are '+ (str(after)))
print('Total '+ (str(before-after))+' entries were dropped.')
# Out:
# Total entries with duplicates were 10841
# Total entries after duplicates were dropped are 10358
# Total 483 entries were dropped.

# %%
ddf # we have successfully removed duplicate values and the new shape of 10358 rows × 13 columns is realised.
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10353     4.5      38                 53M       5,000+  Free     0
# 10354     5.0       4                3.6M         100+  Free     0
# 10355     NaN       3                9.5M       1,000+  Free     0
# 10356     4.5     114  Varies with device       1,000+  Free     0
# 10357     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10353       Everyone                  Education     July 25, 2017
# 10354       Everyone                  Education      July 6, 2018
# 10355       Everyone                    Medical  January 20, 2017
# 10356     Mature 17+          Books & Reference  January 19, 2015
# 10357       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10353                1.48          4.1 and up
# 10354                 1.0          4.1 and up
# 10355                 1.0          2.2 and up
# 10356  Varies with device  Varies with device
# 10357  Varies with device  Varies with device
#
# [10358 rows x 13 columns]

# %%
duplicate =df.groupby(['App']).agg({'Category': 'count'}).reset_index()
duplicate = duplicate.sort_values(by=['Category'], ascending=False)
duplicate.head(20)
# Out:
#                                                     App  Category
# 7302                                             ROBLOX         9
# 1934  CBS Sports App - Scores, News, Stats & Watch Live         8
# 2364                                   Candy Crush Saga         7
# 3504                     Duolingo: Learn Languages Free         7
# 101                                         8 Ball Pool         7
# 3730                                               ESPN         7
# 1651  Bleacher Report: sports news, scores, & highli...         6
# 9290                                    Zombie Catchers         6
# 7896   Sniper 3D Gun Shooter: Free Shooting Games - FPS         6
# 8304                                       Temple Run 2         6
# 1800                                     Bubble Shooter         6
# 6601                                               Nick         6
# 1744                                         Bowmasters         6
# 9584                                         slither.io         6
# 8080                                     Subway Surfers         6
# 5148                                         Helix Jump         6
# 4376                                   Farm Heroes Saga         5
# 731                                 Angry Birds Classic         5
# 9192        Yahoo Fantasy Sports - #1 Rated Fantasy App         5
# 5962                                         MLB At Bat         5

# %%
ddf[ddf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
ddf[ddf['App']=='Candy Crush Saga']
# Out:
#                    App Category  Rating   Reviews Size      Installs  Type  \
# 1448  Candy Crush Saga     GAME     4.4  22426677  74M  500,000,000+  Free
# 1497  Candy Crush Saga     GAME     4.4  22428456  74M  500,000,000+  Free
# 1626  Candy Crush Saga     GAME     4.4  22429716  74M  500,000,000+  Free
# 1652  Candy Crush Saga     GAME     4.4  22430188  74M  500,000,000+  Free
# 3547  Candy Crush Saga   FAMILY     4.4  22419455  74M  500,000,000+  Free
#
#      Price Content Rating  Genres  Last Updated Current Ver Android Ver
# 1448     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up
# 1497     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up
# 1626     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up
# 1652     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up
# 3547     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up

# %%
ddf[ddf['App']=='ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1446  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
# 1494  ROBLOX     GAME     4.5  4447346  67M  100,000,000+  Free     0
# 1538  ROBLOX     GAME     4.5  4448791  67M  100,000,000+  Free     0
# 1625  ROBLOX     GAME     4.5  4449882  67M  100,000,000+  Free     0
# 1653  ROBLOX     GAME     4.5  4449910  67M  100,000,000+  Free     0
# 1786  ROBLOX   FAMILY     4.5  4449910  67M  100,000,000+  Free     0
# 1857  ROBLOX   FAMILY     4.5  4450855  67M  100,000,000+  Free     0
# 1956  ROBLOX   FAMILY     4.5  4450890  67M  100,000,000+  Free     0
# 4072  ROBLOX   FAMILY     4.5  4443407  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1446   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1494   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1538   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1625   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1786   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1857   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1956   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 4072   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver
# 1446  2.347.225742  4.1 and up
# 1494  2.347.225742  4.1 and up
# 1538  2.347.225742  4.1 and up
# 1625  2.347.225742  4.1 and up
# 1653  2.347.225742  4.1 and up
# 1786  2.347.225742  4.1 and up
# 1857  2.347.225742  4.1 and up
# 1956  2.347.225742  4.1 and up
# 4072  2.347.225742  4.1 and up

# %% [markdown]
# # Data   Cleaning
#  “The more data we have, the more likely we are to drown in it.”
#  —Nassim Taleb
#
#  “More data beats clever algorithms, but better data beats more data.”
#  — Peter Norvig`

# %% [markdown]
# ### **Rating**

# %%
ddf['Rating'].head()
# Out:
# 0    4.1
# 1    3.9
# 2    4.7
# 3    4.5
# 4    4.3
# Name: Rating, dtype: float64

# %%
ddf.boxplot() # Since rating can range from 1 to 5 we can observe the presence of an outlier.

# %%
ddf.hist();

# %%
ddf[ddf.Rating>5] # We observe the data frame [9989] has shifted values. ['NaN' , 1.9 , 19.0 , '3.0M', '1,000+','Free', 0, 'Everyone'	, 'NaN', 'February 11, 2018' , '1.0.19' , 4.0  ]
# Out:
#                                           App Category  Rating Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
ddf.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
ddf.drop([9990],inplace=True) # dropping the row to maintain logical consistency

# %%
ddf.reset_index(drop=True, inplace=True) # resetting index after dropping column

# %%
ddf.iloc[9987:9995]
# Out:
#                               App         Category  Rating Reviews  Size  \
# 9987  TownWiFi | Wi-Fi Everywhere    COMMUNICATION     3.9    2372   58M
# 9988                   Jazz Wi-Fi    COMMUNICATION     3.4      49  4.0M
# 9989             Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 9990      osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 9991                 Sat-Fi Voice    COMMUNICATION     3.4      37   14M
# 9992             Wi-Fi Visualizer            TOOLS     3.9     132  2.6M
# 9993        Lennox iComfort Wi-Fi        LIFESTYLE     3.0     552  7.6M
# 9994  Sci-Fi Sounds and Ringtones  PERSONALIZATION     3.6     128   11M
#
#          Installs  Type Price Content Rating           Genres  \
# 9987     500,000+  Free     0       Everyone    Communication
# 9988      10,000+  Free     0       Everyone    Communication
# 9989     100,000+  Free     0       Everyone  Personalization
# 9990  10,000,000+  Free     0       Everyone            Tools
# 9991       1,000+  Free     0       Everyone    Communication
# 9992      50,000+  Free     0       Everyone            Tools
# 9993      50,000+  Free     0       Everyone        Lifestyle
# 9994      10,000+  Free     0       Everyone  Personalization
#
#             Last Updated Current Ver   Android Ver
# 9987      August 2, 2018       4.2.1    4.2 and up
# 9988   February 10, 2017         0.1    2.3 and up
# 9989      August 5, 2014       3.0.0  4.0.3 and up
# 9990      August 7, 2018     6.06.14    4.4 and up
# 9991   November 21, 2014     2.2.1.5    2.2 and up
# 9992        May 17, 2017       0.0.9    2.3 and up
# 9993      March 22, 2017      2.0.15  2.3.3 and up
# 9994  September 27, 2017         4.0    4.0 and up

# %%
ddf.hist(); # After treating the outlier we observe the rating values range from 1 to 5

# %%
ddf['Rating'].isnull().sum() # we observe there are 1465 null values in ratings column
# Out:
# 1465

# %%
sns.set(rc={'figure.figsize':(11.7,8.25)}) #Plot Before we fill nan values 
ax = sns.distplot(ddf['Rating'])

# %%
impute_median=ddf['Rating'].median()                     # You may note that the data is skewed it is not recommended to use the mean for replacing the missing values
ddf['Rating']=ddf['Rating'].fillna(impute_median)      # Using mean values for replacing missing values may not create a great model and hence gets ruled out.

# %% [markdown]
# As the distribution is skewed we will impute through mode
# When the data is skewed, it is good to consider using the mode value for replacing the missing values

# %%
sns.set(rc={'figure.figsize':(11.7,8.25)}) #Plot after we fill NaN values, we can observe little to no devation from the original plot. 
ax = sns.distplot(ddf['Rating'])

# %% [markdown]
# ### **Install & Price**

# %%
ddf[('Installs')].unique() # we observe that there are unwanted characters in the dataset and the data type of the data is of object type.
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
ddf[('Price')].unique() # we observe that there are unwanted characters in the dataset and the data type of the data is of object type.
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
chars_to_remove = ['+', ',' , '$' ]
# List of column names to clean
cols_to_clean = ['Installs', 'Price']

# Loop for each column
for col in cols_to_clean:
    # Replace each character with an empty string
    for char in chars_to_remove:
        ddf[col] = ddf[col].astype(str).str.replace(char, '')

# %% [markdown]
# Price

# %%
 # Convert col to numeric
ddf['Price'] = pd.to_numeric(ddf['Price'])

# %%
ddf[('Price')].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
ddf['Price'].isnull().sum()# checking for null values
# Out:
# 0

# %%
ddf[('Price')].describe() # We can observe that the data type is changed to float type
# Out:
# count    10357.000000
# mean         1.030800
# std         16.278625
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        400.000000
# Name: Price, dtype: float64

# %%
#Create a box plot for the price column
plt.boxplot(ddf.Price)
plt.show()

# %%
ddf.shape
# Out:
# (10357, 13)

# %%
print(ddf[ddf.Price>100].shape)  # We observe that there are 20 apps which are outliers for price app 
Expen= ddf[ddf.Price>100]
Expen
# Out:
# (20, 13)
#                                     App      Category  Rating Reviews Size  \
# 3745             most expensive app (H)        FAMILY     4.3       6  1.5
# 3908                         💎 I'm rich     LIFESTYLE     3.8     718   26
# 3913           I'm Rich - Trump Edition     LIFESTYLE     3.6     275  7.3
# 4895                          I am rich     LIFESTYLE     3.8    3547  1.8
# 4898                     I am Rich Plus        FAMILY     4.0     856  8.7
# 4899                      I am rich VIP     LIFESTYLE     3.8     411  2.6
# 4900                  I Am Rich Premium       FINANCE     4.1    1867  4.7
# 4901                I am extremely Rich     LIFESTYLE     2.9      41  2.9
# 4902                         I am Rich!       FINANCE     3.8      93   22
# 4903                 I am rich(premium)       FINANCE     3.5     472  0.9
# 4906                      I Am Rich Pro        FAMILY     4.4     201  2.7
# 4908     I am rich (Most expensive app)       FINANCE     4.1     129  2.7
# 4910                          I Am Rich        FAMILY     3.6     217  4.9
# 4913                          I am Rich       FINANCE     4.3     180  3.8
# 4917                 I AM RICH PRO PLUS       FINANCE     4.0      36   41
# 6158            BP Fitness Lead Scanner        EVENTS     4.3       0  6.7
# 6226                      cronometra-br  PRODUCTIVITY     4.3       0  5.4
# 9238                       EP Cook Book       MEDICAL     4.3       0  3.2
# 9436                        Eu Sou Rico       FINANCE     4.3       0  1.4
# 9453  I'm Rich/Eu sou Rico/أنا غني/我很有錢     LIFESTYLE     4.3       0   40
#
#      Installs  Type   Price Content Rating         Genres       Last Updated  \
# 3745      100  Paid  399.99       Everyone  Entertainment      July 16, 2018
# 3908    10000  Paid  399.99       Everyone      Lifestyle     March 11, 2018
# 3913    10000  Paid  400.00       Everyone      Lifestyle        May 3, 2018
# 4895   100000  Paid  399.99       Everyone      Lifestyle   January 12, 2018
# 4898    10000  Paid  399.99       Everyone  Entertainment       May 19, 2018
# 4899    10000  Paid  299.99       Everyone      Lifestyle      July 21, 2018
# 4900    50000  Paid  399.99       Everyone        Finance  November 12, 2017
# 4901     1000  Paid  379.99       Everyone      Lifestyle       July 1, 2018
# 4902     1000  Paid  399.99       Everyone        Finance  December 11, 2017
# 4903     5000  Paid  399.99       Everyone        Finance        May 1, 2017
# 4906     5000  Paid  399.99       Everyone  Entertainment       May 30, 2017
# 4908     1000  Paid  399.99           Teen        Finance   December 6, 2017
# 4910    10000  Paid  389.99       Everyone  Entertainment      June 22, 2018
# 4913     5000  Paid  399.99       Everyone        Finance     March 22, 2018
# 4917     1000  Paid  399.99       Everyone        Finance      June 25, 2018
# 6158        1  Paid  109.99       Everyone         Events    August 23, 2017
# 6226        0  Paid  154.99       Everyone   Productivity  November 24, 2017
# 9238        0  Paid  200.00       Everyone        Medical      July 26, 2015
# 9436        0  Paid  394.99       Everyone        Finance      July 11, 2018
# 9453        0  Paid  399.99       Everyone      Lifestyle   December 1, 2017
#
#      Current Ver   Android Ver
# 3745         1.0    7.0 and up
# 3908       1.0.0    4.4 and up
# 3913       1.0.1    4.1 and up
# 4895         2.0  4.0.3 and up
# 4898         3.0    4.4 and up
# 4899       1.1.1    4.3 and up
# 4900         1.6    4.0 and up
# 4901         1.0    4.0 and up
# 4902         1.0    4.1 and up
# 4903         3.4    4.4 and up
# 4906        1.54    1.6 and up
# 4908           2  4.0.3 and up
# 4910         1.5    4.2 and up
# 4913         1.0    4.2 and up
# 4917       1.0.2    4.1 and up
# 6158       0.0.1    4.1 and up
# 6226       1.0.0    4.1 and up
# 9238         1.0    3.0 and up
# 9436         1.0  4.0.3 and up
# 9453       MONEY    4.1 and up

# %%
#ddf=ddf[ddf.Price<=100]

# %%
ddf.shape #Shape of the Dataset changes from (10357, 13)
# Out:
# (10357, 13)

# %%
#Create a box plot for the price column
plt.boxplot(ddf.Price)
plt.show()

# %%
ddf[ddf.Price>0].Price.plot.box() # Box plot of Paid apps
plt.show()

# %%
plt.hist(ddf.Price)
plt.show()

# %%
#ddf[ddf.Price > 30]
# Out:
#                                 App   Category  Rating Reviews Size Installs  \
# 1995      Vargo Anesthesia Mega App    MEDICAL     4.6      92   32     1000
# 2043        A Manual of Acupuncture    MEDICAL     3.5     214   68     1000
# 2122      Language Therapy: Aphasia    MEDICAL     4.3      10   28     1000
# 2137                   LTC AS Legal    MEDICAL     4.0       6  1.3      100
# 3682  Norwegian For Kids & Babies F     FAMILY     4.3       0   14        5
# 4904               I am Rich Person  LIFESTYLE     4.2     134  1.8     1000
# 6100      Dr.Dice - Sic bo analyzer     FAMILY     4.3       2  8.5       10
# 9249                        Lean EQ   BUSINESS     4.3       6   10       10
# 9424                    Eu sou Rico    FINANCE     4.3       0  2.6        0
#
#       Type  Price Content Rating         Genres        Last Updated  \
# 1995  Paid  79.99       Everyone        Medical       June 18, 2018
# 2043  Paid  33.99       Everyone        Medical     October 2, 2017
# 2122  Paid  74.99       Everyone        Medical       June 25, 2018
# 2137  Paid  39.99       Everyone        Medical       April 4, 2018
# 3682  Paid  39.99       Everyone      Education  September 24, 2015
# 4904  Paid  37.99       Everyone      Lifestyle       July 18, 2017
# 6100  Paid  46.99       Everyone  Entertainment    November 5, 2016
# 9249  Paid  89.99       Everyone       Business   February 14, 2017
# 9424  Paid  30.99       Everyone        Finance     January 9, 2018
#
#      Current Ver   Android Ver
# 1995        19.0  4.0.3 and up
# 2043      2.1.35    4.0 and up
# 2122       3.1.1  4.0.3 and up
# 2137       3.0.1    4.1 and up
# 3682         1.0    4.0 and up
# 4904         1.0  4.0.3 and up
# 6100         1.0  4.0.3 and up
# 9249         1.0    4.1 and up
# 9424         1.0    4.0 and up

# %%
#print(ddf[ddf.Price > 30].shape)
#ddf.shape
# Out:
# (0, 13)
# (10328, 13)

# %%
#ddf=ddf[ddf.Price<30]

# %%
#ddf.shape ## Shape of the Dataset changes from (10357, 13)
# Out:
# (10357, 13)

# %%
#ddf[(ddf.Type == "Free") & (ddf.Price > 0)] # Checking data for logical inconsistency, there are none present
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
ddf_free=ddf[ddf.Price<=0.0];
ddf_paid=ddf[ddf.Price>=0.0];

# %%
ddf_paid[ddf_paid['Price']==0]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10352                                   Sya9a Maroc - FR               FAMILY
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10354                             Parkinson Exercices FR              MEDICAL
# 10355                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 0         4.1      159  19.0     10000  Free    0.0       Everyone
# 1         3.9      967  14.0    500000  Free    0.0       Everyone
# 2         4.7    87510   8.7   5000000  Free    0.0       Everyone
# 3         4.5   215644  25.0  50000000  Free    0.0           Teen
# 4         4.3      967   2.8    100000  Free    0.0       Everyone
# ...       ...      ...   ...       ...   ...    ...            ...
# 10352     4.5       38  53.0      5000  Free    0.0       Everyone
# 10353     5.0        4   3.6       100  Free    0.0       Everyone
# 10354     4.3        3   9.5      1000  Free    0.0       Everyone
# 10355     4.5      114   NaN      1000  Free    0.0     Mature 17+
# 10356     4.5   398307  19.0  10000000  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10352                  Education     July 25, 2017                1.48
# 10353                  Education      July 6, 2018                 1.0
# 10354                    Medical  January 20, 2017                 1.0
# 10355          Books & Reference  January 19, 2015  Varies with device
# 10356                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 0                   4.0.3
# 1                   4.0.3
# 2                   4.0.3
# 3                     4.2
# 4                     4.4
# ...                   ...
# 10352                 4.1
# 10353                 4.1
# 10354                 2.2
# 10355  Varies with device
# 10356  Varies with device
#
# [9587 rows x 13 columns]

# %% [markdown]
# Installs

# %%
ddf.sort_values(by='Installs')
# Out:
#                                     App        Category  Rating   Reviews  \
# 9453  I'm Rich/Eu sou Rico/أنا غني/我很有錢       LIFESTYLE     4.3         0
# 6226                      cronometra-br    PRODUCTIVITY     4.3         0
# 8390             Test Application DT 02  ART_AND_DESIGN     4.3         0
# 9424                        Eu sou Rico         FINANCE     4.3         0
# 9238                       EP Cook Book         MEDICAL     4.3         0
# ...                                 ...             ...     ...       ...
# 2252                           Snapchat          SOCIAL     4.0  17014787
# 2248                      Facebook Lite          SOCIAL     4.3   8606259
# 1652                   Candy Crush Saga            GAME     4.4  22430188
# 3425                           Snapchat          SOCIAL     4.0  17000166
# 2849       Gboard - the Google Keyboard           TOOLS     4.2   1859115
#
#                     Size   Installs  Type   Price Content Rating  \
# 9453                 40M          0  Paid  399.99       Everyone
# 6226                5.4M          0  Paid  154.99       Everyone
# 8390                1.2M          0  Free    0.00       Everyone
# 9424                2.6M          0  Paid   30.99       Everyone
# 9238                3.2M          0  Paid  200.00       Everyone
# ...                  ...        ...   ...     ...            ...
# 2252  Varies with device  500000000  Free    0.00           Teen
# 2248  Varies with device  500000000  Free    0.00           Teen
# 1652                 74M  500000000  Free    0.00       Everyone
# 3425  Varies with device  500000000  Free    0.00           Teen
# 2849  Varies with device  500000000  Free    0.00       Everyone
#
#             Genres       Last Updated         Current Ver         Android Ver
# 9453     Lifestyle   December 1, 2017               MONEY          4.1 and up
# 6226  Productivity  November 24, 2017               1.0.0          4.1 and up
# 8390  Art & Design     March 14, 2017                 4.0          4.2 and up
# 9424       Finance    January 9, 2018                 1.0          4.0 and up
# 9238       Medical      July 26, 2015                 1.0          3.0 and up
# ...            ...                ...                 ...                 ...
# 2252        Social      July 30, 2018  Varies with device  Varies with device
# 2248        Social     August 1, 2018  Varies with device  Varies with device
# 1652        Casual       July 5, 2018           1.129.0.2          4.1 and up
# 3425        Social      July 30, 2018  Varies with device  Varies with device
# 2849         Tools      July 31, 2018  Varies with device  Varies with device
#
# [10357 rows x 13 columns]

# %%
 # Convert col to numeric
 ddf['Installs'] = pd.to_numeric(ddf['Installs'])

# %%
ddf[('Installs')].value_counts()
# Out:
# 1000000       1488
# 10000000      1132
# 100000        1129
# 10000         1033
# 1000           890
# 100            710
# 5000000        683
# 500000         517
# 50000          474
# 5000           469
# 10             385
# 100000000      369
# 500            328
# 50000000       272
# 50             204
# 5               82
# 1               67
# 500000000       61
# 1000000000      49
# 0               15
# Name: Installs, dtype: int64

# %%
ddf[('Installs')].describe() # We can observe that the data type is changed to float type
# Out:
# count    1.035700e+04
# mean     1.415776e+07
# std      8.023955e+07
# min      0.000000e+00
# 25%      1.000000e+03
# 50%      1.000000e+05
# 75%      1.000000e+06
# max      1.000000e+09
# Name: Installs, dtype: float64

# %%
ddf['Installs'].isnull().sum() # checking for null values
# Out:
# 0

# %%
ddf.shape
# Out:
# (10357, 13)

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10357 entries, 0 to 10356
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          10357 non-null  float64
#  3   Reviews         10357 non-null  object
#  4   Size            10357 non-null  object
#  5   Installs        10357 non-null  int64
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# ### **Reviews**

# %%
ddf['Reviews'].describe() # we observe that reviews data type is object, for convinience during EDA we will convert it to int data type.
# Out:
# count     10357
# unique     6001
# top           0
# freq        593
# Name: Reviews, dtype: object

# %%
ddf = ddf.astype({'Reviews':'int'})

# %%
ddf['Reviews'].describe()
# Out:
# count    1.035700e+04
# mean     4.059046e+05
# std      2.696778e+06
# min      0.000000e+00
# 25%      3.200000e+01
# 50%      1.680000e+03
# 75%      4.641600e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
ddf['Reviews'].isnull().sum() # there are no null values in Reviews
# Out:
# 0

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
print(ddf[(ddf.Reviews > ddf.Installs)].shape);     # We observe logical inconsistency in our data as the number reviews cannot be greater than number of installs. 
print('\n')
print(ddf.shape);
print('\n')
ddf[(ddf.Reviews > ddf.Installs)]
# Out:
# (11, 13)
#
#
# (10357, 13)
#                                      App         Category  Rating  Reviews  \
# 2173                 KBA-EZ Health Guide          MEDICAL     5.0        4
# 4095   RMEduS - 음성인식을 활용한 R 프로그래밍 실습 시스템           FAMILY     4.3        4
# 4208       Alarmy (Sleep If U Can) - Pro        LIFESTYLE     4.8    10249
# 5355             AX Watch for WatchMaker  PERSONALIZATION     4.3        2
# 5460                            Ra Ga Ba             GAME     5.0        2
# 6049                          Sam.BN Pro            TOOLS     4.3       11
# 6234                    Brick Breaker BR             GAME     5.0        7
# 6933                Trovami se ci riesci             GAME     5.0       11
# 8120                             DN Blog           SOCIAL     5.0       20
# 8615                           DZ Puzzle           FAMILY     4.3       14
# 10214                            Mu.F.O.             GAME     5.0        2
#
#                      Size  Installs  Type  Price Content Rating  \
# 2173                  25M         1  Free   0.00       Everyone
# 4095                  64M         1  Free   0.00       Everyone
# 4208   Varies with device     10000  Paid   2.49       Everyone
# 5355                 238k         1  Paid   0.99       Everyone
# 5460                  20M         1  Paid   1.49       Everyone
# 6049                 2.0M        10  Paid   0.99       Everyone
# 6234                  19M         5  Free   0.00       Everyone
# 6933                 6.1M        10  Free   0.00       Everyone
# 8120                 4.2M        10  Free   0.00           Teen
# 8615                  47M        10  Paid   0.99       Everyone
# 10214                 16M         1  Paid   0.99       Everyone
#
#                 Genres      Last Updated         Current Ver  \
# 2173           Medical    August 2, 2018              1.0.72
# 4095         Education     July 17, 2018               1.0.1
# 4208         Lifestyle     July 30, 2018  Varies with device
# 5355   Personalization   August 18, 2017                 1.0
# 5460            Arcade  February 8, 2017               1.0.4
# 6049             Tools    March 27, 2015               1.0.0
# 6234            Arcade     July 23, 2018                 1.0
# 6933            Arcade    March 11, 2017                 0.1
# 8120            Social     July 23, 2018                 1.0
# 8615            Puzzle    April 22, 2017                 1.2
# 10214           Arcade     March 3, 2017                 1.0
#
#               Android Ver
# 2173         4.0.3 and up
# 4095           4.4 and up
# 4208   Varies with device
# 5355           2.3 and up
# 5460           2.3 and up
# 6049         4.0.3 and up
# 6234           4.1 and up
# 6933           2.3 and up
# 8120           4.0 and up
# 8615           2.3 and up
# 10214          2.3 and up

# %%
ddf = ddf[ddf.Reviews <= ddf.Installs]         #observation with logical inconsistency have been removed. 
print(ddf.shape) 
ddf
# Out:
# (10346, 13)
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10352                                   Sya9a Maroc - FR               FAMILY
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10354                             Parkinson Exercices FR              MEDICAL
# 10355                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# 0         4.1      159                 19M     10000  Free    0.0
# 1         3.9      967                 14M    500000  Free    0.0
# 2         4.7    87510                8.7M   5000000  Free    0.0
# 3         4.5   215644                 25M  50000000  Free    0.0
# 4         4.3      967                2.8M    100000  Free    0.0
# ...       ...      ...                 ...       ...   ...    ...
# 10352     4.5       38                 53M      5000  Free    0.0
# 10353     5.0        4                3.6M       100  Free    0.0
# 10354     4.3        3                9.5M      1000  Free    0.0
# 10355     4.5      114  Varies with device      1000  Free    0.0
# 10356     4.5   398307                 19M  10000000  Free    0.0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10352       Everyone                  Education     July 25, 2017
# 10353       Everyone                  Education      July 6, 2018
# 10354       Everyone                    Medical  January 20, 2017
# 10355     Mature 17+          Books & Reference  January 19, 2015
# 10356       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10352                1.48          4.1 and up
# 10353                 1.0          4.1 and up
# 10354                 1.0          2.2 and up
# 10355  Varies with device  Varies with device
# 10356  Varies with device  Varies with device
#
# [10346 rows x 13 columns]

# %% [markdown]
# ### **Current Var**

# %%
ddf['Current Ver'].head()
# Out:
# 0                 1.0.0
# 1                 2.0.0
# 2                 1.2.4
# 3    Varies with device
# 4                   1.1
# Name: Current Ver, dtype: object

# %%
ddf[ddf['Current Ver'].isnull()]  # checking for null values, we observe 7 null values
# Out:
#                                   App             Category  Rating  Reviews  \
# 15    Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2       55
# 1354             Market Update Helper   LIBRARIES_AND_DEMO     4.1    20145
# 5863           Virtual DJ Sound Mixer                TOOLS     4.2     4010
# 6337                        BT Master               FAMILY     4.3        0
# 6864                      Dots puzzle               FAMILY     4.0      179
# 6938                  Calculate My IQ               FAMILY     4.3       44
# 7260                           UFO-CQ                TOOLS     4.3        1
# 9860                   La Fe de Jesus  BOOKS_AND_REFERENCE     4.3        8
#
#       Size  Installs  Type  Price Content Rating             Genres  \
# 15    2.7M      5000  Free   0.00       Everyone       Art & Design
# 1354   11k   1000000  Free   0.00       Everyone   Libraries & Demo
# 5863  8.7M    500000  Free   0.00       Everyone              Tools
# 6337  222k       100  Free   0.00       Everyone          Education
# 6864   14M     50000  Paid   0.99       Everyone             Puzzle
# 6938  7.2M     10000  Free   0.00       Everyone      Entertainment
# 7260  237k        10  Paid   0.99       Everyone              Tools
# 9860  658k      1000  Free   0.00       Everyone  Books & Reference
#
#            Last Updated Current Ver Android Ver
# 15         June 6, 2018         NaN  4.2 and up
# 1354  February 12, 2013         NaN  1.5 and up
# 5863       May 10, 2017         NaN  4.0 and up
# 6337   November 6, 2016         NaN  1.6 and up
# 6864     April 18, 2018         NaN  4.0 and up
# 6938      April 3, 2017         NaN  2.3 and up
# 7260       July 4, 2016         NaN  2.0 and up
# 9860   January 31, 2017         NaN  3.0 and up

# %%
#Check the most common value in the Android version column
ddf["Current Ver"].value_counts()
# Out:
# Varies with device    1301
# 1.0                    798
# 1.1                    260
# 1.2                    176
# 2.0                    149
#                       ...
# 5.2.8                    1
# 18.201.01                1
# 4.11.0.611033            1
# 8.0.6                    1
# 2.0.148.0                1
# Name: Current Ver, Length: 2830, dtype: int64

# %%
ddf[ddf['Current Ver']=='Varies with device']
# Out:
#                                                  App             Category  \
# 3                              Sketch - Draw & Paint       ART_AND_DESIGN
# 37                                Floor Plan Creator       ART_AND_DESIGN
# 42                        Textgram - write on photos       ART_AND_DESIGN
# 52                     Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 67                                Ulysse Speedometer    AUTO_AND_VEHICLES
# ...                                              ...                  ...
# 10242                                      Posta App  MAPS_AND_NAVIGATION
# 10282                Chat For Strangers - Video Chat               SOCIAL
# 10342      Frim: get new friends on local chat rooms               SOCIAL
# 10355                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# 3         4.5   215644                 25M  50000000  Free    0.0
# 37        4.1    36639  Varies with device   5000000  Free    0.0
# 42        4.4   295221  Varies with device  10000000  Free    0.0
# 52        4.6    17057  Varies with device   1000000  Free    0.0
# 67        4.3    40211  Varies with device   5000000  Free    0.0
# ...       ...      ...                 ...       ...   ...    ...
# 10242     3.6        8  Varies with device      1000  Free    0.0
# 10282     3.4      622  Varies with device    100000  Free    0.0
# 10342     4.0    88486  Varies with device   5000000  Free    0.0
# 10355     4.5      114  Varies with device      1000  Free    0.0
# 10356     4.5   398307                 19M  10000000  Free    0.0
#
#       Content Rating             Genres        Last Updated  \
# 3               Teen       Art & Design        June 8, 2018
# 37          Everyone       Art & Design       July 14, 2018
# 42          Everyone       Art & Design       July 30, 2018
# 52          Everyone    Auto & Vehicles       July 30, 2018
# 67          Everyone    Auto & Vehicles       July 30, 2018
# ...              ...                ...                 ...
# 10242       Everyone  Maps & Navigation  September 27, 2017
# 10282     Mature 17+             Social        May 23, 2018
# 10342     Mature 17+             Social      March 23, 2018
# 10355     Mature 17+  Books & Reference    January 19, 2015
# 10356       Everyone          Lifestyle       July 25, 2018
#
#               Current Ver         Android Ver
# 3      Varies with device          4.2 and up
# 37     Varies with device        2.3.3 and up
# 42     Varies with device  Varies with device
# 52     Varies with device  Varies with device
# 67     Varies with device  Varies with device
# ...                   ...                 ...
# 10242  Varies with device          4.4 and up
# 10282  Varies with device  Varies with device
# 10342  Varies with device  Varies with device
# 10355  Varies with device  Varies with device
# 10356  Varies with device  Varies with device
#
# [1301 rows x 13 columns]

# %%
ddf["Current Ver"].mode()  #Current Ver
# Out:
# 0    Varies with device
# dtype: object

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10346 entries, 0 to 10356
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10346 non-null  object
#  1   Category        10346 non-null  object
#  2   Rating          10346 non-null  float64
#  3   Reviews         10346 non-null  int64
#  4   Size            10346 non-null  object
#  5   Installs        10346 non-null  int64
#  6   Type            10345 non-null  object
#  7   Price           10346 non-null  float64
#  8   Content Rating  10346 non-null  object
#  9   Genres          10346 non-null  object
#  10  Last Updated    10346 non-null  object
#  11  Current Ver     10338 non-null  object
#  12  Android Ver     10344 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
ddf["Current Ver"] = ddf["Current Ver"].fillna(ddf["Current Ver"].mode()[0])

# %%
ddf["Current Ver"].value_counts()
# Out:
# Varies with device    1309
# 1.0                    798
# 1.1                    260
# 1.2                    176
# 2.0                    149
#                       ...
# 5.2.8                    1
# 18.201.01                1
# 4.11.0.611033            1
# 8.0.6                    1
# 2.0.148.0                1
# Name: Current Ver, Length: 2830, dtype: int64

# %%
ddf['Current Ver'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### **Android Var**

# %%
ddf[ddf["Android Ver"].isnull()]  # checking for null values
# Out:
#                          App         Category  Rating  Reviews  Size  \
# 3998  [substratum] Vacuum: P  PERSONALIZATION     4.4      230   11M
# 4035    Pi Dark [substratum]  PERSONALIZATION     4.5      189  2.1M
#
#       Installs  Type  Price Content Rating           Genres    Last Updated  \
# 3998      1000  Paid   1.49       Everyone  Personalization   July 20, 2018
# 4035     10000  Free   0.00       Everyone  Personalization  March 27, 2018
#
#      Current Ver Android Ver
# 3998         4.4         NaN
# 4035         1.1         NaN

# %%
# Removing 'and up' from Android Ver
ddf['Android Ver'] = ddf['Android Ver'].replace({' and up':''}, regex=True)

# %%
#Check the most common value in the Android version column
ddf["Android Ver"].value_counts()
# Out:
# 4.1                   2378
# 4.0.3                 1449
# 4.0                   1336
# Varies with device    1220
# 4.4                    893
# 2.3                    638
# 5.0                    546
# 4.2                    387
# 2.3.3                  279
# 2.2                    239
# 3.0                    237
# 4.3                    235
# 2.1                    133
# 1.6                    116
# 6.0                     58
# 7.0                     42
# 3.2                     36
# 2.0                     32
# 5.1                     22
# 1.5                     20
# 4.4W                    11
# 3.1                     10
# 2.0.1                    7
# 8.0                      6
# 7.1                      3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0                      2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
ddf["Android Ver"].mode()
# Out:
# 0    4.1
# dtype: object

# %%
#Fill up the nulls in the Android Version column with the above value
ddf["Android Ver"] = ddf["Android Ver"].fillna(ddf["Android Ver"].mode()[0])

# %%
#Check the nulls in the Android version column again to cross-verify
print(ddf[ddf["Android Ver"].isnull()])
print ('\n')

ddf["Android Ver"].value_counts()
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []
# 4.1                   2380
# 4.0.3                 1449
# 4.0                   1336
# Varies with device    1220
# 4.4                    893
# 2.3                    638
# 5.0                    546
# 4.2                    387
# 2.3.3                  279
# 2.2                    239
# 3.0                    237
# 4.3                    235
# 2.1                    133
# 1.6                    116
# 6.0                     58
# 7.0                     42
# 3.2                     36
# 2.0                     32
# 5.1                     22
# 1.5                     20
# 4.4W                    11
# 3.1                     10
# 2.0.1                    7
# 8.0                      6
# 7.1                      3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0                      2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10346 entries, 0 to 10356
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10346 non-null  object
#  1   Category        10346 non-null  object
#  2   Rating          10346 non-null  float64
#  3   Reviews         10346 non-null  int64
#  4   Size            10346 non-null  object
#  5   Installs        10346 non-null  int64
#  6   Type            10345 non-null  object
#  7   Price           10346 non-null  float64
#  8   Content Rating  10346 non-null  object
#  9   Genres          10346 non-null  object
#  10  Last Updated    10346 non-null  object
#  11  Current Ver     10346 non-null  object
#  12  Android Ver     10346 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Type

# %%
ddf["Type"] = ddf["Type"].fillna(ddf["Type"].mode()[0])

# %%
ddf.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ### **Size**

# %%
ddf['Size'].value_counts()
# Out:
# Varies with device    1525
# 11                     188
# 13                     186
# 12                     186
# 14                     182
#                       ...
# 430k                     1
# 429k                     1
# 200k                     1
# 460k                     1
# 619k                     1
# Name: Size, Length: 460, dtype: int64

# %%
ddf['Size'].unique()
# Out:
# array(['19', '14', '8.7', '25', '2.8', '5.6', '29', '33', '3.1', '28',
#        '12', '20', '21', '37', '2.7', '5.5', '17', '39', '31', '4.2',
#        '7.0', '23', '6.0', '6.1', '4.6', '9.2', '5.2', '11', '24',
#        'Varies with device', '9.4', '15', '10', '1.2', '26', '8.0', '7.9',
#        '56', '57', '35', '54', '201k', '3.6', '5.7', '8.6', '2.4', '27',
#        '2.5', '16', '3.4', '8.9', '3.9', '2.9', '38', '32', '5.4', '18',
#        '1.1', '2.2', '4.5', '9.8', '52', '9.0', '6.7', '30', '2.6', '7.1',
#        '3.7', '22', '7.4', '6.4', '3.2', '8.2', '9.9', '4.9', '9.5',
#        '5.0', '5.9', '13', '73', '6.8', '3.5', '4.0', '2.3', '7.2', '2.1',
#        '42', '7.3', '9.1', '55', '23k', '6.5', '1.5', '7.5', '51', '41',
#        '48', '8.5', '46', '8.3', '4.3', '4.7', '3.3', '40', '7.8', '8.8',
#        '6.6', '5.1', '61', '66', '79k', '8.4', '118k', '44', '695k',
#        '1.6', '6.2', '18k', '53', '1.4', '3.0', '5.8', '3.8', '9.6', '45',
#        '63', '49', '77', '4.4', '4.8', '70', '6.9', '9.3', '10.0', '8.1',
#        '36', '84', '97', '2.0', '1.9', '1.8', '5.3', '47', '556k', '526k',
#        '76', '7.6', '59', '9.7', '78', '72', '43', '7.7', '6.3', '334k',
#        '34', '93', '65', '79', '100', '58', '50', '68', '64', '67', '60',
#        '94', '232k', '99', '624k', '95', '8.5k', '41k', '292k', '11k',
#        '80', '1.7', '74', '62', '69', '75', '98', '85', '82', '96', '87',
#        '71', '86', '91', '81', '92', '83', '88', '704k', '862k', '899k',
#        '378k', '266k', '375k', '1.3', '975k', '980k', '4.1', '89', '696k',
#        '544k', '525k', '920k', '779k', '853k', '720k', '713k', '772k',
#        '318k', '58k', '241k', '196k', '857k', '51k', '953k', '865k',
#        '251k', '930k', '540k', '313k', '746k', '203k', '26k', '314k',
#        '239k', '371k', '220k', '730k', '756k', '91k', '293k', '17k',
#        '74k', '14k', '317k', '78k', '924k', '902k', '818k', '81k', '939k',
#        '169k', '45k', '475k', '965k', '90', '545k', '61k', '283k', '655k',
#        '714k', '93k', '872k', '121k', '322k', '1.0', '976k', '172k',
#        '549k', '206k', '954k', '444k', '717k', '210k', '609k', '308k',
#        '705k', '306k', '904k', '473k', '175k', '350k', '383k', '454k',
#        '421k', '70k', '812k', '442k', '842k', '417k', '412k', '459k',
#        '478k', '335k', '782k', '721k', '430k', '429k', '192k', '200k',
#        '460k', '728k', '496k', '816k', '414k', '506k', '887k', '613k',
#        '243k', '569k', '778k', '683k', '592k', '319k', '186k', '840k',
#        '647k', '191k', '373k', '437k', '598k', '716k', '585k', '982k',
#        '222k', '219k', '55k', '948k', '323k', '691k', '511k', '951k',
#        '963k', '25k', '554k', '351k', '27k', '82k', '208k', '913k',
#        '514k', '551k', '29k', '103k', '898k', '743k', '116k', '153k',
#        '209k', '353k', '499k', '173k', '597k', '809k', '122k', '411k',
#        '400k', '801k', '787k', '237k', '50k', '643k', '986k', '97k',
#        '516k', '837k', '780k', '961k', '269k', '20k', '498k', '600k',
#        '749k', '642k', '881k', '72k', '656k', '601k', '221k', '228k',
#        '108k', '940k', '176k', '33k', '663k', '34k', '942k', '259k',
#        '164k', '458k', '245k', '629k', '28k', '288k', '775k', '785k',
#        '636k', '916k', '994k', '309k', '485k', '914k', '903k', '608k',
#        '500k', '54k', '562k', '847k', '957k', '688k', '811k', '270k',
#        '48k', '329k', '523k', '921k', '874k', '981k', '784k', '280k',
#        '24k', '518k', '754k', '892k', '154k', '860k', '364k', '387k',
#        '626k', '161k', '879k', '39k', '970k', '170k', '141k', '160k',
#        '144k', '143k', '190k', '376k', '193k', '246k', '73k', '658k',
#        '992k', '253k', '420k', '404k', '470k', '226k', '240k', '89k',
#        '234k', '257k', '861k', '467k', '157k', '44k', '676k', '67k',
#        '552k', '885k', '1020k', '582k', '619k'], dtype=object)

# %%
np.nan
# Out:
# nan

# %%
ddf['Size'] = ddf['Size'].map(lambda x: x.rstrip('M'))
ddf['Size'] = ddf['Size'].map(lambda x: str(round((float(x.rstrip('k'))/1024), 1)) if x[-1]=='k' else x)
ddf['Size'] = ddf['Size'].map(lambda x: np.nan if x.startswith('Varies') else x)

# %%
ddf['Size'].unique()
# Out:
# array(['19', '14', '8.7', '25', '2.8', '5.6', '29', '33', '3.1', '28',
#        '12', '20', '21', '37', '2.7', '5.5', '17', '39', '31', '4.2',
#        '7.0', '23', '6.0', '6.1', '4.6', '9.2', '5.2', '11', '24', nan,
#        '9.4', '15', '10', '1.2', '26', '8.0', '7.9', '56', '57', '35',
#        '54', '0.2', '3.6', '5.7', '8.6', '2.4', '27', '2.5', '16', '3.4',
#        '8.9', '3.9', '2.9', '38', '32', '5.4', '18', '1.1', '2.2', '4.5',
#        '9.8', '52', '9.0', '6.7', '30', '2.6', '7.1', '3.7', '22', '7.4',
#        '6.4', '3.2', '8.2', '9.9', '4.9', '9.5', '5.0', '5.9', '13', '73',
#        '6.8', '3.5', '4.0', '2.3', '7.2', '2.1', '42', '7.3', '9.1', '55',
#        '0.0', '6.5', '1.5', '7.5', '51', '41', '48', '8.5', '46', '8.3',
#        '4.3', '4.7', '3.3', '40', '7.8', '8.8', '6.6', '5.1', '61', '66',
#        '0.1', '8.4', '44', '0.7', '1.6', '6.2', '53', '1.4', '3.0', '5.8',
#        '3.8', '9.6', '45', '63', '49', '77', '4.4', '4.8', '70', '6.9',
#        '9.3', '10.0', '8.1', '36', '84', '97', '2.0', '1.9', '1.8', '5.3',
#        '47', '0.5', '76', '7.6', '59', '9.7', '78', '72', '43', '7.7',
#        '6.3', '0.3', '34', '93', '65', '79', '100', '58', '50', '68',
#        '64', '67', '60', '94', '99', '0.6', '95', '80', '1.7', '74', '62',
#        '69', '75', '98', '85', '82', '96', '87', '71', '86', '91', '81',
#        '92', '83', '88', '0.8', '0.9', '0.4', '1.3', '1.0', '4.1', '89',
#        '90'], dtype=object)

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10346 entries, 0 to 10356
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10346 non-null  object
#  1   Category        10346 non-null  object
#  2   Rating          10346 non-null  float64
#  3   Reviews         10346 non-null  int64
#  4   Size            8821 non-null   object
#  5   Installs        10346 non-null  int64
#  6   Type            10346 non-null  object
#  7   Price           10346 non-null  float64
#  8   Content Rating  10346 non-null  object
#  9   Genres          10346 non-null  object
#  10  Last Updated    10346 non-null  object
#  11  Current Ver     10346 non-null  object
#  12  Android Ver     10346 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
ddf['Size'].value_counts()
# Out:
# 11    188
# 12    186
# 13    186
# 14    182
# 15    174
#      ...
# 65     10
# 84      9
# 89      9
# 86      7
# 90      6
# Name: Size, Length: 192, dtype: int64

# %%
ddf['Size'].describe()
# Out:
# count     8821
# unique     192
# top         11
# freq       188
# Name: Size, dtype: object

# %%
ddf=ddf.astype({'Size':float})

# %%
#Plot a histogram for Size as well.
plt.hist(ddf.Size, bins=20)
plt.show()

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### 1.   Find out the number of Installs of the top 10 most expensive app's

# %%
plt.figure(figsize=(20,10))                               #Plotting a bar graph showing the number of installs vs Apps
sns.set_theme(style="darkgrid")
ax = sns.countplot(y='Price', data=Expen)                 #Using Expen dataframe which we created while cleaning Price column
Expen.sort_values(by='Price',ascending=False).head()
# Out:
#                            App   Category  Rating Reviews  Size Installs  \
# 3884  I'm Rich - Trump Edition  LIFESTYLE     3.6     275  7.3M    10000
# 3714    most expensive app (H)     FAMILY     4.3       6  1.5M      100
# 4875                I am Rich!    FINANCE     3.8      93   22M     1000
# 4890        I AM RICH PRO PLUS    FINANCE     4.0      36   41M     1000
# 4886                 I am Rich    FINANCE     4.3     180  3.8M     5000
#
#       Type   Price Content Rating         Genres       Last Updated  \
# 3884  Paid  400.00       Everyone      Lifestyle        May 3, 2018
# 3714  Paid  399.99       Everyone  Entertainment      July 16, 2018
# 4875  Paid  399.99       Everyone        Finance  December 11, 2017
# 4890  Paid  399.99       Everyone        Finance      June 25, 2018
# 4886  Paid  399.99       Everyone        Finance     March 22, 2018
#
#      Current Ver Android Ver
# 3884       1.0.1  4.1 and up
# 3714         1.0  7.0 and up
# 4875         1.0  4.1 and up
# 4890       1.0.2  4.1 and up
# 4886         1.0  4.2 and up

# %% [markdown]
# **i'm Rich - Trump Edition	 is the most expensive application with 5000 installs**

# %% [markdown]
# ### 2.   Which Category has more apps?

# %%
dfg=ddf.sort_values(by='Genres').head()
lables= 'Tools','Entertainment','Education' ,'Medical' ,'Business'

# %% [markdown]
# ### 3.   What is the average size of the free apps & paid apps

# %% [markdown]
# ### 4.   What is the 5 top rated apps.

# %% [markdown]
# ### 5.   How many apps that has more than 50K reviews.

# %%
ddf['Reviews'].mean()
# Out:
# 407476.4188233013

# %%
ddf[ddf['Reviews'] >407476.4188233013]
# Out:
#                                   App             Category  Rating  Reviews  \
# 139              Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6  2914724
# 142                         Wikipedia  BOOKS_AND_REFERENCE     4.4   577550
# 143                     Amazon Kindle  BOOKS_AND_REFERENCE     4.2   814080
# 145      Dictionary - Merriam-Webster  BOOKS_AND_REFERENCE     4.5   454060
# 152                 Google Play Books  BOOKS_AND_REFERENCE     3.9  1433233
# ...                               ...                  ...     ...      ...
# 10023            Rope Hero: Vice Town                 GAME     4.4   452589
# 10029  Flight Simulator: Fly Plane 3D               FAMILY     4.0   660613
# 10152              FRONTLINE COMMANDO                 GAME     4.4  1351833
# 10223  Photo Editor Collage Maker Pro          PHOTOGRAPHY     4.5  1519671
# 10297            Modern Strike Online                 GAME     4.3   834117
#
#                      Size    Installs  Type  Price Content Rating  \
# 139    Varies with device   100000000  Free    0.0           Teen
# 142    Varies with device    10000000  Free    0.0       Everyone
# 143    Varies with device   100000000  Free    0.0           Teen
# 145    Varies with device    10000000  Free    0.0       Everyone
# 152    Varies with device  1000000000  Free    0.0           Teen
# ...                   ...         ...   ...    ...            ...
# 10023                 99M    10000000  Free    0.0     Mature 17+
# 10029                 21M    50000000  Free    0.0       Everyone
# 10152                 12M    10000000  Free    0.0           Teen
# 10223  Varies with device   100000000  Free    0.0       Everyone
# 10297                 44M    10000000  Free    0.0           Teen
#
#                   Genres      Last Updated         Current Ver  \
# 139    Books & Reference    August 1, 2018  Varies with device
# 142    Books & Reference    August 2, 2018  Varies with device
# 143    Books & Reference     July 27, 2018  Varies with device
# 145    Books & Reference      May 18, 2018  Varies with device
# 152    Books & Reference    August 3, 2018  Varies with device
# ...                  ...               ...                 ...
# 10023             Action      July 1, 2018                 2.2
# 10029         Simulation     March 1, 2017                1.32
# 10152             Action  October 28, 2013               3.0.3
# 10223        Photography  February 1, 2018  Varies with device
# 10297             Action     July 30, 2018              1.25.4
#
#               Android Ver
# 139    Varies with device
# 142    Varies with device
# 143    Varies with device
# 145    Varies with device
# 152    Varies with device
# ...                   ...
# 10023          4.0 and up
# 10029          2.3 and up
# 10152          2.1 and up
# 10223  Varies with device
# 10297          4.1 and up
#
# [1049 rows x 13 columns]

# %% [markdown]
# ### 6. What is the average price of the apps for each genre with each installs numbers.

# %% [markdown]
# ### 7. How many apps have rating > 4.7 and what is thier avg price.

# %% [markdown]
# ### 8. How much google earned from the 5,000,000+ installed apps

# %% [markdown]
# ### 9. What is the max and min size for free and paid apps.

# %% [markdown]
# ### 10. is there a correlation between rating, Reviews, Size with the price of the app

# %% [markdown]
# ### 11. How many apps for each type for each content reading

# %% [markdown]
# ### 12. How many apps that can work on android version 4.2

# %% [markdown]
# ### 13.   What is the highest Category of apps ?

# %%
dfc=df[ 'Category'].value_counts().head()

# %%
import seaborn as sns
plt.figure(figsize=(20,10))
sns.set_theme(style="darkgrid")
ax = sns.countplot(y='Category', data=ddf)

print(dfc);                                                                                   # We observe that apps with the Genre of family has the maximum apps witvh vaLue 1972
# Out:
# FAMILY      1972
# GAME        1144
# TOOLS        843
# MEDICAL      463
# BUSINESS     460
# Name: Category, dtype: int64

# %% [markdown]
# ## free app vs paid app

# %%
ddf['Type'].value_counts().plot.pie(figsize = (10,7), autopct='%1.1f%%',colors = sns.color_palette('muted'))
plt.legend()

# %%
ddf.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
ddf.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ##highest installed app

# %%
installed_app = ddf[ddf['Installs']== 1000000000 ]
installed_app[['App','Installs']].head(10)
# Out:
#                                           App    Installs
# 152                         Google Play Books  1000000000
# 302              Google Chrome: Fast & Secure  1000000000
# 304                                  Hangouts  1000000000
# 337                        WhatsApp Messenger  1000000000
# 338  Messenger – Text and Video Chat for Free  1000000000
# 340                                  Hangouts  1000000000
# 357              Google Chrome: Fast & Secure  1000000000
# 397                                     Gmail  1000000000
# 410                                  Hangouts  1000000000
# 744                         Google Play Games  1000000000

# %% [markdown]
# ## app with zero installment

# %%
installed_app = ddf[ddf['Installs']==0]
installed_app[['App','Installs','Price']]
# Out:
#                                                App  Installs  Price
# 3982  Popsicle Launcher for Android P 9.0 launcher         0   1.49
# 4824                       Ak Parti Yardım Toplama         0  13.99
# 5003                        AP Series Solution Pro         0   1.99
# 5462                    Ain Arabic Kids Alif Ba ta         0   2.99
# 6951                                 Pekalongan CJ         0   0.00
# 7598                                    CX Network         0   0.00
# 8131                             Sweden Newspapers         0   0.00
# 8388                        Test Application DT 02         0   0.00
# 8665                     Command & Conquer: Rivals         0   0.00
# 8854                      EG | Explore Folegandros         0   3.99

# %%
installed_app2 = ddf[ddf['Price']==399]
installed_app[['App','Price']]
# Out:
#                                                App  Price
# 3982  Popsicle Launcher for Android P 9.0 launcher   1.49
# 4824                       Ak Parti Yardım Toplama  13.99
# 5003                        AP Series Solution Pro   1.99
# 5462                    Ain Arabic Kids Alif Ba ta   2.99
# 6951                                 Pekalongan CJ   0.00
# 7598                                    CX Network   0.00
# 8131                             Sweden Newspapers   0.00
# 8388                        Test Application DT 02   0.00
# 8665                     Command & Conquer: Rivals   0.00
# 8854                      EG | Explore Folegandros   3.99

# %%
ddf['Price'].sort_values(ascending=True).tail(20)
# Out:
# 6354    17.99
# 4878    18.99
# 6864    19.40
# 5256    19.90
# 4553    19.99
# 6994    19.99
# 2110    19.99
# 4365    19.99
# 8236    19.99
# 2098    24.99
# 2109    24.99
# 9091    24.99
# 2063    24.99
# 3694    25.99
# 8621    28.99
# 7845    29.99
# 5006    29.99
# 2097    29.99
# 2634    29.99
# 2078    29.99
# Name: Price, dtype: float64

# %%
ddf['Price'].describe()
# Out:
# count    10317.000000
# mean         0.296921
# std          1.610363
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         29.990000
# Name: Price, dtype: float64

# %%
ddf['Installs'].max()
# Out:
# 1000000000

# %%
ddf['Installs'].min()
# Out:
# 0

# %%
ddf['Installs'].mean()
# Out:
# 14212627.823107492
